# %% [markdown]
# ***
# ### ==> 1. Data Import and Data Exploration
# ***

# %% [markdown]
# ### Datasets
# We have 5 csv file
#
#    - dim_date.csv
#    - dim_hotels.csv
#    - dim_rooms.csv
#    - fact_aggregated_bookings
#    - fact_bookings.csv

# %%
## EDA , try to understand our data, try to make sense from all our data
import pandas as pd

# %%
df_bookings=pd.read_csv('3_project_hospitality_analysis/datasets/fact_bookings.csv')
df_bookings.head(3)
# Out:
#          booking_id  property_id booking_date check_in_date checkout_date  \
# 0  May012216558RT11        16558     27-04-22      1/5/2022      2/5/2022
# 1  May012216558RT12        16558     30-04-22      1/5/2022      2/5/2022
# 2  May012216558RT13        16558     28-04-22      1/5/2022      4/5/2022
#
#    no_guests room_category booking_platform  ratings_given booking_status  \
# 0       -3.0           RT1    direct online            1.0    Checked Out
# 1        2.0           RT1           others            NaN      Cancelled
# 2        2.0           RT1          logtrip            5.0    Checked Out
#
#    revenue_generated  revenue_realized
# 0              10010             10010
# 1               9100              3640
# 2            9100000              9100

# %%
df_bookings.shape
# Out:
# (134590, 12)

# %%
df_bookings.room_category.unique()
# Out:
# array(['RT1', 'RT2', 'RT3', 'RT4'], dtype=object)

# %%
df_bookings.booking_platform.unique()
# Out:
# array(['direct online', 'others', 'logtrip', 'tripster', 'makeyourtrip',
#        'journey', 'direct offline'], dtype=object)

# %%
## to check total bookings of platforms
df_bookings.booking_platform.value_counts()
# Out:
# booking_platform
# others            55066
# makeyourtrip      26898
# logtrip           14756
# direct online     13379
# tripster           9630
# journey            8106
# direct offline     6755
# Name: count, dtype: int64

# %%
df_bookings.booking_platform.value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='booking_platform'>

# %%
df_bookings.describe()
# Out:
#          property_id      no_guests  ratings_given  revenue_generated  \
# count  134590.000000  134587.000000   56683.000000       1.345900e+05
# mean    18061.113493       2.036170       3.619004       1.537805e+04
# std      1093.055847       1.034885       1.235009       9.303604e+04
# min     16558.000000     -17.000000       1.000000       6.500000e+03
# 25%     17558.000000       1.000000       3.000000       9.900000e+03
# 50%     17564.000000       2.000000       4.000000       1.350000e+04
# 75%     18563.000000       2.000000       5.000000       1.800000e+04
# max     19563.000000       6.000000       5.000000       2.856000e+07
#
#        revenue_realized
# count     134590.000000
# mean       12696.123256
# std         6928.108124
# min         2600.000000
# 25%         7600.000000
# 50%        11700.000000
# 75%        15300.000000
# max        45220.000000

# %%
df_bookings.revenue_generated.min(),df_bookings.revenue_generated.max()
# Out:
# (6500, 28560000)

# %%
df_date=pd.read_csv('3_project_hospitality_analysis/datasets/dim_date.csv')
df_hotels=pd.read_csv('3_project_hospitality_analysis/datasets/dim_hotels.csv')
df_rooms=pd.read_csv('3_project_hospitality_analysis/datasets/dim_rooms.csv')
df_agg_bookings=pd.read_csv('3_project_hospitality_analysis/datasets/fact_aggregated_bookings.csv')

# %%
df_hotels.head(3)
# Out:
#    property_id  property_name  category    city
# 0        16558   Atliq Grands    Luxury   Delhi
# 1        16559  Atliq Exotica    Luxury  Mumbai
# 2        16560     Atliq City  Business   Delhi

# %%
df_hotels.category.value_counts()
# Out:
# category
# Luxury      16
# Business     9
# Name: count, dtype: int64

# %%
df_hotels.city.value_counts().sort_values()
# Out:
# city
# Delhi        5
# Hyderabad    6
# Bangalore    6
# Mumbai       8
# Name: count, dtype: int64

# %%
df_hotels.city.value_counts().sort_values().plot(kind='bar')
# Out:
# <Axes: xlabel='city'>

# %% [markdown]
# ## Explore Aggregate bookings file

# %%
df_agg_bookings.head(3)
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity
# 0        16559      1-May-22           RT1                   25      30.0
# 1        19562      1-May-22           RT1                   28      30.0
# 2        19563      1-May-22           RT1                   23      30.0

# %%
df_agg_bookings.groupby('property_id')['successful_bookings'].sum()
# Out:
# property_id
# 16558    3153
# 16559    7338
# 16560    4693
# 16561    4418
# 16562    4820
# 16563    7211
# 17558    5053
# 17559    6142
# 17560    6013
# 17561    5183
# 17562    3424
# 17563    6337
# 17564    3982
# 18558    4475
# 18559    5256
# 18560    6638
# 18561    6458
# 18562    7333
# 18563    4737
# 19558    4400
# 19559    4729
# 19560    6079
# 19561    5736
# 19562    5812
# 19563    5413
# Name: successful_bookings, dtype: int64

# %%
df_agg_bookings[df_agg_bookings.successful_bookings>df_agg_bookings.capacity]
# Out:
#       property_id check_in_date room_category  successful_bookings  capacity
# 3           17558      1-May-22           RT1                   30      19.0
# 12          16563      1-May-22           RT1                  100      41.0
# 4136        19558     11-Jun-22           RT2                   50      39.0
# 6209        19560      2-Jul-22           RT1                  123      26.0
# 8522        19559     25-Jul-22           RT1                   35      24.0
# 9194        18563     31-Jul-22           RT4                   20      18.0

# %%
## bookings with highest capacity
df_agg_bookings[df_agg_bookings.capacity==df_agg_bookings.capacity.max()]
# Out:
#       property_id check_in_date room_category  successful_bookings  capacity
# 27          17558      1-May-22           RT2                   38      50.0
# 128         17558      2-May-22           RT2                   27      50.0
# 229         17558      3-May-22           RT2                   26      50.0
# 328         17558      4-May-22           RT2                   27      50.0
# 428         17558      5-May-22           RT2                   29      50.0
# ...           ...           ...           ...                  ...       ...
# 8728        17558     27-Jul-22           RT2                   22      50.0
# 8828        17558     28-Jul-22           RT2                   21      50.0
# 8928        17558     29-Jul-22           RT2                   23      50.0
# 9028        17558     30-Jul-22           RT2                   32      50.0
# 9128        17558     31-Jul-22           RT2                   30      50.0
#
# [92 rows x 5 columns]

# %% [markdown]
# ## Data Cleaning

# %%
df_bookings.describe()
# Out:
#          property_id      no_guests  ratings_given  revenue_generated  \
# count  134590.000000  134587.000000   56683.000000       1.345900e+05
# mean    18061.113493       2.036170       3.619004       1.537805e+04
# std      1093.055847       1.034885       1.235009       9.303604e+04
# min     16558.000000     -17.000000       1.000000       6.500000e+03
# 25%     17558.000000       1.000000       3.000000       9.900000e+03
# 50%     17564.000000       2.000000       4.000000       1.350000e+04
# 75%     18563.000000       2.000000       5.000000       1.800000e+04
# max     19563.000000       6.000000       5.000000       2.856000e+07
#
#        revenue_realized
# count     134590.000000
# mean       12696.123256
# std         6928.108124
# min         2600.000000
# 25%         7600.000000
# 50%        11700.000000
# 75%        15300.000000
# max        45220.000000

# %%
df_bookings[df_bookings.no_guests<=0]
# Out:
#                booking_id  property_id booking_date check_in_date  \
# 0        May012216558RT11        16558     27-04-22      1/5/2022
# 3        May012216558RT14        16558     28-04-22      1/5/2022
# 17924    May122218559RT44        18559    12/5/2022     12/5/2022
# 18020    May122218561RT22        18561     8/5/2022     12/5/2022
# 18119   May122218562RT311        18562     5/5/2022     12/5/2022
# 18121   May122218562RT313        18562    10/5/2022     12/5/2022
# 56715    Jun082218562RT12        18562     5/6/2022      8/6/2022
# 119765  Jul202219560RT220        19560     19-07-22      20-07-22
# 134586   Jul312217564RT47        17564     30-07-22      31-07-22
#
#        checkout_date  no_guests room_category booking_platform  ratings_given  \
# 0           2/5/2022       -3.0           RT1    direct online            1.0
# 3           2/5/2022       -2.0           RT1           others            NaN
# ...

# %%
df_bookings=df_bookings[df_bookings.no_guests>0]

# %%
df_bookings.describe()
# Out:
#          property_id      no_guests  ratings_given  revenue_generated  \
# count  134578.000000  134578.000000   56679.000000       1.345780e+05
# mean    18061.143315       2.036744       3.619048       1.537804e+04
# std      1093.053454       1.031710       1.234970       9.304015e+04
# min     16558.000000       1.000000       1.000000       6.500000e+03
# 25%     17558.000000       1.000000       3.000000       9.900000e+03
# 50%     17564.000000       2.000000       4.000000       1.350000e+04
# 75%     18563.000000       2.000000       5.000000       1.800000e+04
# max     19563.000000       6.000000       5.000000       2.856000e+07
#
#        revenue_realized
# count     134578.000000
# mean       12696.011822
# std         6927.841641
# min         2600.000000
# 25%         7600.000000
# 50%        11700.000000
# 75%        15300.000000
# max        45220.000000

# %%
df_bookings.head(2)
# Out:
#          booking_id  property_id booking_date check_in_date checkout_date  \
# 1  May012216558RT12        16558     30-04-22      1/5/2022      2/5/2022
# 2  May012216558RT13        16558     28-04-22      1/5/2022      4/5/2022
#
#    no_guests room_category booking_platform  ratings_given booking_status  \
# 1        2.0           RT1           others            NaN      Cancelled
# 2        2.0           RT1          logtrip            5.0    Checked Out
#
#    revenue_generated  revenue_realized
# 1               9100              3640
# 2            9100000              9100

# %%
df_bookings.revenue_generated.min(),df_bookings.revenue_generated.max()
# Out:
# (6500, 28560000)

# %%
aver,std=df_bookings.revenue_generated.mean(), df_bookings.revenue_generated.std()

# %%
## setting limits for outliers
higher_limit=aver+3*std
higher_limit
# Out:
# 294498.50173198653

# %%
## Checking if there is any negative value in revenue_generated
df_bookings[df_bookings.revenue_generated<0]
# Out:
# Empty DataFrame
# Columns: [booking_id, property_id, booking_date, check_in_date, checkout_date, no_guests, room_category, booking_platform, ratings_given, booking_status, revenue_generated, revenue_realized]
# Index: []

# %%
## Checking outliers 
df_bookings[df_bookings.revenue_generated>higher_limit]
# Out:
#                booking_id  property_id booking_date check_in_date  \
# 2        May012216558RT13        16558     28-04-22      1/5/2022
# 111      May012216559RT32        16559     29-04-22      1/5/2022
# 315      May012216562RT22        16562     28-04-22      1/5/2022
# 562     May012217559RT118        17559     26-04-22      1/5/2022
# 129176   Jul282216562RT26        16562     21-07-22      28-07-22
#
#        checkout_date  no_guests room_category booking_platform  ratings_given  \
# 2           4/5/2022        2.0           RT1          logtrip            5.0
# 111         2/5/2022        6.0           RT3    direct online            NaN
# 315         4/5/2022        2.0           RT2   direct offline            3.0
# 562         2/5/2022        2.0           RT1           others            NaN
# 129176      29-07-22        2.0           RT2    direct online            3.0
#
#        booking_status  revenue_generated  revenue_realized
# ...

# %%
## modifying original df by removing those outliers
df_bookings=df_bookings[df_bookings.revenue_generated<higher_limit]
df_bookings.shape
# Out:
# (134573, 12)

# %%
## Checking outliers in revenue_realized
df_bookings.describe()
# Out:
#          property_id      no_guests  ratings_given  revenue_generated  \
# count  134573.000000  134573.000000   56676.000000      134573.000000
# mean    18061.191658       2.036716       3.619045       14915.959776
# std      1093.042273       1.031673       1.234983        6452.676164
# min     16558.000000       1.000000       1.000000        6500.000000
# 25%     17558.000000       1.000000       3.000000        9900.000000
# 50%     17564.000000       2.000000       4.000000       13500.000000
# 75%     18563.000000       2.000000       5.000000       18000.000000
# max     19563.000000       6.000000       5.000000       45220.000000
#
#        revenue_realized
# count     134573.000000
# mean       12695.983585
# std         6927.791692
# min         2600.000000
# 25%         7600.000000
# 50%        11700.000000
# 75%        15300.000000
# max        45220.000000

# %%
higher_limit_realized=df_bookings.revenue_realized.mean()+3*df_bookings.revenue_realized.std()
higher_limit_realized
# Out:
# 33479.3586618449

# %%
df_bookings[df_bookings.revenue_realized>higher_limit_realized]
# Out:
#                booking_id  property_id booking_date check_in_date  \
# 137      May012216559RT41        16559     27-04-22      1/5/2022
# 139      May012216559RT43        16559     1/5/2022      1/5/2022
# 143      May012216559RT47        16559     28-04-22      1/5/2022
# 149     May012216559RT413        16559     24-04-22      1/5/2022
# 222      May012216560RT45        16560     30-04-22      1/5/2022
# ...                   ...          ...          ...           ...
# 134328   Jul312219560RT49        19560     31-07-22      31-07-22
# 134331  Jul312219560RT412        19560     31-07-22      31-07-22
# 134467   Jul312219562RT45        19562     28-07-22      31-07-22
# 134474  Jul312219562RT412        19562     25-07-22      31-07-22
# 134581   Jul312217564RT42        17564     31-07-22      31-07-22
#
#        checkout_date  no_guests room_category booking_platform  ratings_given  \
# 137         7/5/2022        4.0           RT4           others            NaN
# ...

# %%
df_rooms
# Out:
#   room_id    room_class
# 0     RT1      Standard
# 1     RT2         Elite
# 2     RT3       Premium
# 3     RT4  Presidential

# %%
## hence here it is belonging to RT4 i,e presidential rooms most expensive and luxury rooms ,, So hence here we have to check 
## outliers only belonging to RT4 room types , 
df_bookings[df_bookings.room_category=='RT4'].revenue_realized.describe()
# Out:
# count    16071.000000
# mean     23439.308444
# std       9048.599076
# min       7600.000000
# 25%      19000.000000
# 50%      26600.000000
# 75%      32300.000000
# max      45220.000000
# Name: revenue_realized, dtype: float64

# %%
## So higher limit/(OUtlier) for revenue_realized will be
higher_limit_realz=23439.308444 +3*9048.599076
higher_limit_realz
# Out:
# 50585.105672000005

# %%
## hence our limit for outliers is 50k but our max value is 45k so there is no error in this column hence no need to remove any rows

# %% [markdown]
# * Checking if there is any null values

# %%
df_bookings.isnull().sum()
## So having null values in ratings_given column is totally okay coz some people don't gives feedback or ratings they just checked out and leave
# Out:
# booking_id               0
# property_id              0
# booking_date             0
# check_in_date            0
# checkout_date            0
# no_guests                0
# room_category            0
# booking_platform         0
# ratings_given        77897
# booking_status           0
# revenue_generated        0
# revenue_realized         0
# dtype: int64

# %% [markdown]
# Cleaning df_agg_booking file

# %%
df_agg_bookings.head()
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity
# 0        16559      1-May-22           RT1                   25      30.0
# 1        19562      1-May-22           RT1                   28      30.0
# 2        19563      1-May-22           RT1                   23      30.0
# 3        17558      1-May-22           RT1                   30      19.0
# 4        16558      1-May-22           RT1                   18      19.0

# %%
## Checking and handling null values
df_agg_bookings.isnull().sum()
# Out:
# property_id            0
# check_in_date          0
# room_category          0
# successful_bookings    0
# capacity               2
# dtype: int64

# %%
median=df_agg_bookings.capacity.median()
df_agg_bookings.capacity.fillna(median,inplace=True)
df_agg_bookings.isnull().sum()
# Out:
# property_id            0
# check_in_date          0
# room_category          0
# successful_bookings    0
# capacity               0
# dtype: int64

# %%
df_agg_bookings[df_agg_bookings.successful_bookings>df_agg_bookings.capacity
## these are wrong entries we have to remove these
# Out:
#       property_id check_in_date room_category  successful_bookings  capacity
# 3           17558      1-May-22           RT1                   30      19.0
# 12          16563      1-May-22           RT1                  100      41.0
# 4136        19558     11-Jun-22           RT2                   50      39.0
# 6209        19560      2-Jul-22           RT1                  123      26.0
# 8522        19559     25-Jul-22           RT1                   35      24.0
# 9194        18563     31-Jul-22           RT4                   20      18.0

# %%
df_agg_bookings=df_agg_bookings[df_agg_bookings.successful_bookings<=df_agg_bookings.capacity]
df_agg_bookings.head()
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity
# 0        16559      1-May-22           RT1                   25      30.0
# 1        19562      1-May-22           RT1                   28      30.0
# 2        19563      1-May-22           RT1                   23      30.0
# 4        16558      1-May-22           RT1                   18      19.0
# 5        17560      1-May-22           RT1                   28      40.0

# %% [markdown]
# ## Data Transformation

# %%
df_agg_bookings.head()
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity
# 0        16559      1-May-22           RT1                   25      30.0
# 1        19562      1-May-22           RT1                   28      30.0
# 2        19563      1-May-22           RT1                   23      30.0
# 4        16558      1-May-22           RT1                   18      19.0
# 5        17560      1-May-22           RT1                   28      40.0

# %%
## Adding a column with name Occupancy percentage

# %%
df_agg_bookings['Occupancy_percentage']=df_agg_bookings.successful_bookings/df_agg_bookings.capacity
df_agg_bookings
# Out:
#       property_id check_in_date room_category  successful_bookings  capacity  \
# 0           16559      1-May-22           RT1                   25      30.0
# 1           19562      1-May-22           RT1                   28      30.0
# 2           19563      1-May-22           RT1                   23      30.0
# 4           16558      1-May-22           RT1                   18      19.0
# 5           17560      1-May-22           RT1                   28      40.0
# ...           ...           ...           ...                  ...       ...
# 9195        16563     31-Jul-22           RT4                   13      18.0
# 9196        16559     31-Jul-22           RT4                   13      18.0
# 9197        17558     31-Jul-22           RT4                    3       6.0
# 9198        19563     31-Jul-22           RT4                    3       6.0
# 9199        17561     31-Jul-22           RT4                    3       4.0
#
#       Occupancy_percentage
# ...

# %%
## rounding off the values

# %%
df_agg_bookings.Occupancy_percentage=df_agg_bookings.Occupancy_percentage.apply(lambda x: round(x*100,2))
df_agg_bookings.head()
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity  \
# 0        16559      1-May-22           RT1                   25      30.0
# 1        19562      1-May-22           RT1                   28      30.0
# 2        19563      1-May-22           RT1                   23      30.0
# 4        16558      1-May-22           RT1                   18      19.0
# 5        17560      1-May-22           RT1                   28      40.0
#
#    Occupancy_percentage
# 0                 83.33
# 1                 93.33
# 2                 76.67
# 4                 94.74
# 5                 70.00

# %% [markdown]
# There are various types of data transformations that you may have to perform based on the need. Few examples of data transformations are,
#
# Creating new colum
# n s
# Normalizat
# i on
# Merging
# d ata
# Aggregation

# %% [markdown]
# ## Insights Generation

# %% [markdown]
# **1. What is an average occupancy rate in each of the room categories**

# %%
df_agg_bookings
df_agg_bookings.groupby('room_category')['Occupancy_percentage'].mean().round(2)
# Out:
# room_category
# RT1    57.89
# RT2    58.01
# RT3    58.03
# RT4    59.28
# Name: Occupancy_percentage, dtype: float64

# %%
df_agg_bookings.head(2)
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity  \
# 0        16559      1-May-22           RT1                   25      30.0
# 1        19562      1-May-22           RT1                   28      30.0
#
#    Occupancy_percentage
# 0                 83.33
# 1                 93.33

# %%
df_rooms.head()
# Out:
#   room_id    room_class
# 0     RT1      Standard
# 1     RT2         Elite
# 2     RT3       Premium
# 3     RT4  Presidential

# %%
df=pd.merge(df_agg_bookings,df_rooms , left_on='room_category',right_on='room_id')
df.head()
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity  \
# 0        16559      1-May-22           RT1                   25      30.0
# 1        19562      1-May-22           RT1                   28      30.0
# 2        19563      1-May-22           RT1                   23      30.0
# 3        16558      1-May-22           RT1                   18      19.0
# 4        17560      1-May-22           RT1                   28      40.0
#
#    Occupancy_percentage room_id room_class
# 0                 83.33     RT1   Standard
# 1                 93.33     RT1   Standard
# 2                 76.67     RT1   Standard
# 3                 94.74     RT1   Standard
# 4                 70.00     RT1   Standard

# %%
df.groupby('room_class')['Occupancy_percentage'].mean().round(2)
# Out:
# room_class
# Elite           58.01
# Premium         58.03
# Presidential    59.28
# Standard        57.89
# Name: Occupancy_percentage, dtype: float64

# %%
## Deleting extra column
df.drop('room_id',axis=1,inplace=True)
df.head()
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity  \
# 0        16559      1-May-22           RT1                   25      30.0
# 1        19562      1-May-22           RT1                   28      30.0
# 2        19563      1-May-22           RT1                   23      30.0
# 3        16558      1-May-22           RT1                   18      19.0
# 4        17560      1-May-22           RT1                   28      40.0
#
#    Occupancy_percentage room_class
# 0                 83.33   Standard
# 1                 93.33   Standard
# 2                 76.67   Standard
# 3                 94.74   Standard
# 4                 70.00   Standard

# %% [markdown]
# **2. Print Average occupancy rate per city**

# %%
df_hotels.head()
# Out:
#    property_id  property_name  category    city
# 0        16558   Atliq Grands    Luxury   Delhi
# 1        16559  Atliq Exotica    Luxury  Mumbai
# 2        16560     Atliq City  Business   Delhi
# 3        16561      Atliq Blu    Luxury   Delhi
# 4        16562      Atliq Bay    Luxury   Delhi

# %%
df=pd.merge(df,df_hotels,on='property_id',how="left")
df.head()
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity  \
# 0        16559      1-May-22           RT1                   25      30.0
# 1        19562      1-May-22           RT1                   28      30.0
# 2        19563      1-May-22           RT1                   23      30.0
# 3        16558      1-May-22           RT1                   18      19.0
# 4        17560      1-May-22           RT1                   28      40.0
#
#    Occupancy_percentage room_class  property_name  category       city
# 0                 83.33   Standard  Atliq Exotica    Luxury     Mumbai
# 1                 93.33   Standard      Atliq Bay    Luxury  Bangalore
# 2                 76.67   Standard   Atliq Palace  Business  Bangalore
# 3                 94.74   Standard   Atliq Grands    Luxury      Delhi
# 4                 70.00   Standard     Atliq City  Business     Mumbai

# %%
## Average occupancy rate per city
df.groupby('city')['Occupancy_percentage'].mean().round(2)
# Out:
# city
# Bangalore    56.33
# Delhi        61.51
# Hyderabad    58.12
# Mumbai       57.91
# Name: Occupancy_percentage, dtype: float64

# %%
df.groupby('city')['Occupancy_percentage'].mean().plot(kind='bar')
# Out:
# <Axes: xlabel='city'>

# %% [markdown]
# **3. When was the occupany better? Weekday or weekend**

# %%
df_date.head()
# Out:
#         date  mmm yy week no  day_type
# 0  01-May-22  May 22    W 19   weekend
# 1  02-May-22  May 22    W 19  weekeday
# 2  03-May-22  May 22    W 19  weekeday
# 3  04-May-22  May 22    W 19  weekeday
# 4  05-May-22  May 22    W 19  weekeday

# %%
df=pd.merge(df,df_date,left_on='check_in_date',right_on='date')
df.head(2)
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity  \
# 0        18560     10-May-22           RT1                   19      30.0
# 1        19562     10-May-22           RT1                   18      30.0
#
#    Occupancy_percentage room_class property_name  category       city  \
# 0                 63.33   Standard    Atliq City  Business  Hyderabad
# 1                 60.00   Standard     Atliq Bay    Luxury  Bangalore
#
#         date  mmm yy week no  day_type
# 0  10-May-22  May 22    W 20  weekeday
# 1  10-May-22  May 22    W 20  weekeday

# %%
df=df.drop(columns=['date_y','mmm yy_y','week no_y','day_type_y'])
df.head()
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity  \
# 0        18560     10-May-22           RT1                   19      30.0
# 1        19562     10-May-22           RT1                   18      30.0
# 2        19563     10-May-22           RT1                   16      30.0
# 3        17558     10-May-22           RT1                   11      19.0
# 4        16558     10-May-22           RT1                   10      19.0
#
#    Occupancy_percentage room_class property_name  category       city
# 0                 63.33   Standard    Atliq City  Business  Hyderabad
# 1                 60.00   Standard     Atliq Bay    Luxury  Bangalore
# 2                 53.33   Standard  Atliq Palace  Business  Bangalore
# 3                 57.89   Standard  Atliq Grands    Luxury     Mumbai
# 4                 52.63   Standard  Atliq Grands    Luxury      Delhi

# %%
df.groupby('day_type')['Occupancy_percentage'].mean().round(2)
# Out:
# day_type
# weekeday    50.88
# weekend     72.34
# Name: Occupancy_percentage, dtype: float64

# %% [markdown]
# **4. In the month of june what is the occupancy for different cities?**

# %%
df.head(2)
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity  \
# 0        18560     10-May-22           RT1                   19      30.0
# 1        19562     10-May-22           RT1                   18      30.0
#
#    Occupancy_percentage room_class property_name  category       city  \
# 0                 63.33   Standard    Atliq City  Business  Hyderabad
# 1                 60.00   Standard     Atliq Bay    Luxury  Bangalore
#
#         date  mmm yy week no  day_type
# 0  10-May-22  May 22    W 20  weekeday
# 1  10-May-22  May 22    W 20  weekeday

# %%
df['mmm yy'].unique()
# Out:
# array(['May 22', 'Jun 22', 'Jul 22'], dtype=object)

# %%
## Filtering and storing only JUN data
df_jun_22=df[df['mmm yy']=='Jun 22']
df_jun_22.head()
# Out:
#       property_id check_in_date room_category  successful_bookings  capacity  \
# 2200        16559     10-Jun-22           RT1                   20      30.0
# 2201        19562     10-Jun-22           RT1                   19      30.0
# 2202        19563     10-Jun-22           RT1                   17      30.0
# 2203        17558     10-Jun-22           RT1                    9      19.0
# 2204        16558     10-Jun-22           RT1                   11      19.0
#
#       Occupancy_percentage room_class  property_name  category       city  \
# 2200                 66.67   Standard  Atliq Exotica    Luxury     Mumbai
# 2201                 63.33   Standard      Atliq Bay    Luxury  Bangalore
# 2202                 56.67   Standard   Atliq Palace  Business  Bangalore
# 2203                 47.37   Standard   Atliq Grands    Luxury     Mumbai
# 2204                 57.89   Standard   Atliq Grands    Luxury      Delhi
#
#            date  mmm yy week no  day_type
# ...

# %%
df_jun_22.groupby('city')['Occupancy_percentage'].mean().round(2).sort_values(ascending=False)
## Occupancy of different cities in june month
# Out:
# city
# Delhi        62.47
# Hyderabad    58.46
# Mumbai       58.38
# Bangalore    56.44
# Name: Occupancy_percentage, dtype: float64

# %%
## Appending new-month data file to df

# %%
df_aug=pd.read_csv("3_project_hospitality_analysis/datasets/new_data_august.csv")
df_aug.head()
# Out:
#    property_id  property_name  category       city room_category room_class  \
# 0        16559  Atliq Exotica    Luxury     Mumbai           RT1   Standard
# 1        19562      Atliq Bay    Luxury  Bangalore           RT1   Standard
# 2        19563   Atliq Palace  Business  Bangalore           RT1   Standard
# 3        19558   Atliq Grands    Luxury  Bangalore           RT1   Standard
# 4        19560     Atliq City  Business  Bangalore           RT1   Standard
#
#   check_in_date  mmm yy week no  day_type  successful_bookings  capacity  \
# 0     01-Aug-22  Aug-22    W 32  weekeday                   30        30
# 1     01-Aug-22  Aug-22    W 32  weekeday                   21        30
# 2     01-Aug-22  Aug-22    W 32  weekeday                   23        30
# 3     01-Aug-22  Aug-22    W 32  weekeday                   30        40
# 4     01-Aug-22  Aug-22    W 32  weekeday                   20        26
#
#      occ%
# 0  100.00
# 1   70.00
# 2   76.67
# 3   75.00
# 4   76.92

# %%
df_latest=pd.concat([df,df_aug],ignore_index=True,axis=0)
df_latest.tail()
# Out:
#       property_id check_in_date room_category  successful_bookings  capacity  \
# 6499        19563     01-Aug-22           RT1                   23      30.0
# 6500        19558     01-Aug-22           RT1                   30      40.0
# 6501        19560     01-Aug-22           RT1                   20      26.0
# 6502        17561     01-Aug-22           RT1                   18      26.0
# 6503        17564     01-Aug-22           RT1                   10      16.0
#
#       Occupancy_percentage room_class  property_name  category       city  \
# 6499                   NaN   Standard   Atliq Palace  Business  Bangalore
# 6500                   NaN   Standard   Atliq Grands    Luxury  Bangalore
# 6501                   NaN   Standard     Atliq City  Business  Bangalore
# 6502                   NaN   Standard      Atliq Blu    Luxury     Mumbai
# 6503                   NaN   Standard  Atliq Seasons  Business     Mumbai
#
#      date  mmm yy week no  day_type   occ%
# ...

# %% [markdown]
# **6. Print revenue realize per city**

# %%
df_bookings.head()
df_bookings.shape
# Out:
# (134573, 12)

# %%
df_hotels.head(2)
# Out:
#    property_id  property_name category    city
# 0        16558   Atliq Grands   Luxury   Delhi
# 1        16559  Atliq Exotica   Luxury  Mumbai

# %%
df_bookings_city=pd.merge(df_bookings,df_hotels,on='property_id')
df_bookings_city.head(2)
#df_bookings_city.shape
# Out:
#          booking_id  property_id booking_date check_in_date checkout_date  \
# 0  May012216558RT12        16558     30-04-22      1/5/2022      2/5/2022
# 1  May012216558RT15        16558     27-04-22      1/5/2022      2/5/2022
#
#    no_guests room_category booking_platform  ratings_given booking_status  \
# 0        2.0           RT1           others            NaN      Cancelled
# 1        4.0           RT1    direct online            5.0    Checked Out
#
#    revenue_generated  revenue_realized property_name category   city
# 0               9100              3640  Atliq Grands   Luxury  Delhi
# 1              10920             10920  Atliq Grands   Luxury  Delhi

# %%
df_bookings_city.groupby('city')['revenue_realized'].sum().sort_values(ascending=False)
# Out:
# city
# Mumbai       668569251
# Bangalore    420383550
# Hyderabad    325179310
# Delhi        294404488
# Name: revenue_realized, dtype: int64

# %% [markdown]
# **7. Print month by month revenue**

# %%
df_bookings_city.info()
df_bookings_city.tail(3)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 134573 entries, 0 to 134572
# Data columns (total 15 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   booking_id         134573 non-null  object
#  1   property_id        134573 non-null  int64
#  2   booking_date       134573 non-null  object
#  3   check_in_date      134573 non-null  object
#  4   checkout_date      134573 non-null  object
#  5   no_guests          134573 non-null  float64
#  6   room_category      134573 non-null  object
#  7   booking_platform   134573 non-null  object
#  8   ratings_given      56676 non-null   float64
#  9   booking_status     134573 non-null  object
#  10  revenue_generated  134573 non-null  int64
#  11  revenue_realized   134573 non-null  int64
#  12  property_name      134573 non-null  object
#  13  category           134573 non-null  object
#  14  city               134573 non-null  object
# ...

# %%
df_date.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 92 entries, 0 to 91
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   date      92 non-null     object
#  1   mmm yy    92 non-null     object
#  2   week no   92 non-null     object
#  3   day_type  92 non-null     object
# dtypes: object(4)
# memory usage: 3.0+ KB

# %%
## before merging these data we have to convert the date col type to date
df_date['date']=pd.to_datetime(df_date['date'])
df_date.head(3)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_13600\2530841427.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df_date['date']=pd.to_datetime(df_date['date'])
#         date  mmm yy week no  day_type
# 0 2022-05-01  May 22    W 19   weekend
# 1 2022-05-02  May 22    W 19  weekeday
# 2 2022-05-03  May 22    W 19  weekeday

# %%
df_bookings_city['check_in_date']=pd.to_datetime(df_bookings_city['check_in_date'],dayfirst=True, errors='coerce')
df_bookings_city.head(3)
# Out:
#          booking_id  property_id booking_date check_in_date checkout_date  \
# 0  May012216558RT12        16558     30-04-22    2022-05-01      2/5/2022
# 1  May012216558RT15        16558     27-04-22    2022-05-01      2/5/2022
# 2  May012216558RT16        16558     1/5/2022    2022-05-01      3/5/2022
#
#    no_guests room_category booking_platform  ratings_given booking_status  \
# 0        2.0           RT1           others            NaN      Cancelled
# 1        4.0           RT1    direct online            5.0    Checked Out
# 2        2.0           RT1           others            4.0    Checked Out
#
#    revenue_generated  revenue_realized property_name category   city
# 0               9100              3640  Atliq Grands   Luxury  Delhi
# 1              10920             10920  Atliq Grands   Luxury  Delhi
# 2               9100              9100  Atliq Grands   Luxury  Delhi

# %%
df_bookings_all=pd.merge(df_bookings_city,df_date, left_on='check_in_date',right_on='date')
df_bookings_all.head(2)
# Out:
#          booking_id  property_id booking_date check_in_date checkout_date  \
# 0  May012216558RT12        16558     30-04-22    2022-05-01      2/5/2022
# 1  May012216558RT15        16558     27-04-22    2022-05-01      2/5/2022
#
#    no_guests room_category booking_platform  ratings_given booking_status  \
# 0        2.0           RT1           others            NaN      Cancelled
# 1        4.0           RT1    direct online            5.0    Checked Out
#
#    revenue_generated  revenue_realized property_name category   city  \
# 0               9100              3640  Atliq Grands   Luxury  Delhi
# 1              10920             10920  Atliq Grands   Luxury  Delhi
#
#         date  mmm yy week no day_type
# 0 2022-05-01  May 22    W 19  weekend
# 1 2022-05-01  May 22    W 19  weekend

# %%
df_bookings_all.groupby('mmm yy')['revenue_realized'].sum().sort_values(ascending=False)
# Out:
# mmm yy
# Jul 22    243180932
# May 22    234353183
# Jun 22    229637640
# Name: revenue_realized, dtype: int64

# %% [markdown]
# **8. Revenue realized per hotel type?**

# %%
df_bookings_all.head(2)
# Out:
#          booking_id  property_id booking_date check_in_date checkout_date  \
# 0  May012216558RT12        16558     30-04-22    2022-05-01      2/5/2022
# 1  May012216558RT15        16558     27-04-22    2022-05-01      2/5/2022
#
#    no_guests room_category booking_platform  ratings_given booking_status  \
# 0        2.0           RT1           others            NaN      Cancelled
# 1        4.0           RT1    direct online            5.0    Checked Out
#
#    revenue_generated  revenue_realized property_name category   city  \
# 0               9100              3640  Atliq Grands   Luxury  Delhi
# 1              10920             10920  Atliq Grands   Luxury  Delhi
#
#         date  mmm yy week no day_type
# 0 2022-05-01  May 22    W 19  weekend
# 1 2022-05-01  May 22    W 19  weekend

# %%
df_bookings_all.head(2)
df_bookings_all.property_name.unique()
# Out:
# array(['Atliq Grands', 'Atliq Exotica', 'Atliq City', 'Atliq Blu',
#        'Atliq Bay', 'Atliq Palace', 'Atliq Seasons'], dtype=object)

# %%
df_bookings_all.groupby('property_name')['revenue_realized'].sum().sort_values(ascending=False)
# Out:
# property_name
# Atliq Exotica    133619226
# Atliq Palace     125553143
# Atliq City       118290783
# Atliq Blu        108108129
# Atliq Bay        107516312
# Atliq Grands      87245939
# Atliq Seasons     26838223
# Name: revenue_realized, dtype: int64

# %% [markdown]
# **9. Print average rating per city**

# %%
df_bookings_all.groupby('city')['ratings_given'].mean().round(2).sort_values(ascending=False)
# Out:
# city
# Delhi        3.79
# Mumbai       3.66
# Hyderabad    3.65
# Bangalore    3.41
# Name: ratings_given, dtype: float64

# %% [markdown]
# **10. Print pie chart of revenue realized per booking platform**

# %%
df_bookings_all.head(2)
# Out:
#          booking_id  property_id booking_date check_in_date checkout_date  \
# 0  May012216558RT12        16558     30-04-22    2022-05-01      2/5/2022
# 1  May012216558RT15        16558     27-04-22    2022-05-01      2/5/2022
#
#    no_guests room_category booking_platform  ratings_given booking_status  \
# 0        2.0           RT1           others            NaN      Cancelled
# 1        4.0           RT1    direct online            5.0    Checked Out
#
#    revenue_generated  revenue_realized property_name category   city  \
# 0               9100              3640  Atliq Grands   Luxury  Delhi
# 1              10920             10920  Atliq Grands   Luxury  Delhi
#
#         date  mmm yy week no day_type
# 0 2022-05-01  May 22    W 19  weekend
# 1 2022-05-01  May 22    W 19  weekend

# %%
df_bookings_all.booking_platform.unique()
# Out:
# array(['others', 'direct online', 'logtrip', 'tripster', 'makeyourtrip',
#        'journey', 'direct offline'], dtype=object)

# %%
df_bookings_all.groupby('booking_platform')['revenue_realized'].sum().plot(kind='pie')
# Out:
# <Axes: ylabel='revenue_realized'>
